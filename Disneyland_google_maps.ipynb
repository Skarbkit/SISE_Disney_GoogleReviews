# %%
import time 
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By


from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.support.ui import WebDriverWait

from selenium.common.exceptions import NoSuchElementException
import time
import csv

import pandas as pd
from datetime import datetime

# %%
path=Service(r'C:\Users\f_ati\OneDrive\Documents\Master\Master2\TextMining\Projet\chromedriver_win32\chromedriver.exe')

#ouvrir la page 
driver=webdriver.Chrome(service=path)

url = 'https://www.google.com/maps/place/Disneyland+Paris/@48.8673892,2.7791083,17z/data=!4m7!3m6!1s0x47e61d19ca7ae2bd:0x57faf8cb6310e660!8m2!3d48.8673858!4d2.783593!9m1!1b1'

#accepter les cookies
driver.get(url)
valide=driver.find_element(By.XPATH,'//*[@id="yDmH0d"]/c-wiz/div/div/div/div[2]/div[1]/div[3]/div[1]/div[1]/form[2]/div/div/button/span')
valide.click()
time.sleep(2)
    


#scroll
total_number_of_reviews = driver.find_element(By.XPATH,'//*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]/div/div[2]/div[2]').text.split(" ")[0]
total_number_of_reviews = total_number_of_reviews.replace(u"\u202f","") if u"\u202f" in total_number_of_reviews else int(total_number_of_reviews)
total_number_of_reviews=int(total_number_of_reviews)
scrollable_div = driver.find_element(By.XPATH,'//*[@id="QA0Szd"]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]')
#Scroll as many times as necessary to load all reviews
for i in range(0,round(4)):#(total_number_of_reviews / 100)):
    driver.execute_script('arguments[0].scrollTop = arguments[0].scrollHeight',scrollable_div)
    time.sleep(0.3)

# %%
response = BeautifulSoup(driver.page_source, 'html.parser')
r = response.find_all('div', class_="m6QErb")


rev_dict = {'Review Text': [],
            #'Review Name' : [],
            'Review Time': [],
            'Review Role' : [],
            #'Review Visite' : [],
            'Review Rate' : []
           }

for rv in r :
    review_text = rv.find_all('span', class_='wiI7pd')
   # review_name = rv.find_all('span', jstcache='331')
    review_date = rv.find_all('span',class_='rsqaWe')
    review_role = rv.find_all('span', jstcache='333') 
    #review_Visite = rv.find_all('span', jstcache='198') 
    review_rate = rv.find_all('span', class_="kvMYJc")
    
    if len(review_text) == 0 : 
        rev_dict['Review Text'].append("")
    else :
        for rv in review_text :
            rev_dict['Review Text'].append(rv.get_text())
            
   # if len(review_name) == 0 :
     #   rev_dict['Review Name'].append("")
   # else:
     #   for rv in review_name : 
      #      rev_dict['Review Name'].append(rv.get_text())
    if len(review_date) == 0:
        rev_dict['Review Time'].append("")
    else:
        for rv in review_date :
            rev_dict['Review Time'].append(rv.get_text())
        
    if len(review_role) == 0 : 
        rev_dict['Review Role'].append("")
        
    else :
        for rv in review_role : 
            rev_dict['Review Role'].append(rv.get_text())
            
    #if len(review_Visite) == 0 : 
     #   rev_dict['Review Visite'].append("")
   # else :
      #  for rv in review_Visite : 
       #     rev_dict['Review Visite'].append(rv.get_text())
 
    for rv in review_rate : 
        attributes_dictionary = rv.attrs
        stars = attributes_dictionary['aria-label']
        rev_dict['Review Rate'].append(stars)
        
d=pd.DataFrame(rev_dict)
d.to_csv("Disneyland.csv")
# Out:
#   File "C:\Users\f_ati\AppData\Local\Temp\ipykernel_9272\4137829925.py", line 5
#     rev_dict = ['Review Text': [],
#                              ^
# SyntaxError: invalid syntax

# %%
print(len(review_date))
#print(len(review_Visite))
print(len(review_rate))
print(len(review_text))
#print(len(review_name))
print(len(review_role))
# Out:
# 30
# 30
# 30
# 30

# %%
print(len(rev_dict['Review Time']))
print(len(rev_dict['Review Role']))
print(len(rev_dict['Review Text']))
print(len(rev_dict['Review Role']))
d=pd.DataFrame(rev_dict)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9272\2386990914.py in <module>
# ----> 1 d=pd.DataFrame(rev_dict)
#
# ~\anaconda3\envs\DineyProject\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     634         elif isinstance(data, dict):
#     635             # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 636             mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     637         elif isinstance(data, ma.MaskedArray):
#     638             import numpy.ma.mrecords as mrecords
#
# ~\anaconda3\envs\DineyProject\lib\site-packages\pandas\core\internals\construction.py in dict_to_mgr(data, index, columns, dtype, typ, copy)
#     500         # TODO: can we get rid of the dt64tz special case above?
#     501
# --> 502     return arrays_to_mgr(arrays, columns, index, dtype=dtype, typ=typ, consolidate=copy)
#     503
#     504
#
# ~\anaconda3\envs\DineyProject\lib\site-packages\pandas\core\internals\construction.py in arrays_to_mgr(arrays, columns, index, dtype, verify_integrity, typ, consolidate)
#     118         # figure out the index, if necessary
#     119         if index is None:
# --> 120             index = _extract_index(arrays)
#     121         else:
#     122             index = ensure_index(index)
#
# ~\anaconda3\envs\DineyProject\lib\site-packages\pandas\core\internals\construction.py in _extract_index(data)
#     672             lengths = list(set(raw_lengths))
#     673             if len(lengths) > 1:
# --> 674                 raise ValueError("All arrays must be of the same length")
#     675
#     676             if have_dicts:
#
# ValueError: All arrays must be of the same length

# %%
rev_dict
# Out:
# {'Review Text': ['',
#   '',
#   'Au vu du nombre d’avis je vais faire court : Magnifique. Féerique. Grandiose. Mais quelle attente. 90min en moyenne par attraction. Je n’ose même pas imaginer aux périodes de fortes affluences. Et puis le prix. Hôtel + 3 jours afin de …',
#   'Les prix ont tellement augmenté en 8 ans, c’est assez dingue.\nLe parc est propre, les mesures Covid-19 bien faite. Toujours des pannes mais ça reste de la mécanique/électronique qui tourne beaucoup donc c’est normal.\nCertaines attractions refaite comme la maison hantée, je n’ai pas vu de différence',
#   "Magique, quel que soit l'âge.\nConnu tout petit, vingt ans plus tard ça marche encore. Tout les employés sont adorables, les attractions marchent toujours aussi bien et l'ambiance également. …",
#   'Nous sommes allé a Disney un jeudi hors vacances scolaires. Le parc nous a fait retomber en enfance : les personnages de nos dessins animés préférés étaient au rendez-vous. Nous avons choisi la période de la Halloween pour profiter de …',
#   "Joli parc, pour les enfants, mais comparé à y a quelques années, c'est tombé bien bas, et les tarifs sont graves malades.\nParc mal entretenu, mal tondu, le personnel pas souriant, pas aimable, bref, …",
#   "Meilleur parc d'attraction de France, de loin. Une journée, mieux avec deux. L'enfant en vous reviendra à l'instant où vous entrerez dans ce parc et ce, quelque soit le nombre de fois où vous irez. Choisissez bien vos jours, lorsque c'est trop bondé, il est difficile d'en profiter pleinement.",
#   "On a A DO RE ! Tout était top pour satisfaire le visiteur, un bémol sur la réservation, en effet Disneyland s'est encaissé 20€ de plus, et n'a jamais eu la correction de répondre au courrier recommandé, et donc de rembourser le trop perçu. …",
#   'Parc est toujours aussi beau et bien entretenu, néanmoins les tarifs restent élevés sans que Disneyland ne se renouvelle plus que ça, et les pannes mécaniques sont assez fréquentes. Cependant, après une période COVID, cela peut se …',
#   "Un lieu magique féerique 😍 la magie est au rendez-vous la décoration et juste magnifique on voyage à travers le temps et le monde, le point négatif l'attente est vraiment longue, donc on ne pas faire plusieurs choses …",
#   "Journée magique 😍\nPremière fois pour mon fils de 4 ans, il a adoré, la magie est présente dès l'arrivée sur le parc. Nous avons eu un super temps, pas trop d'attente, nous avon …",
#   'Comment ne pas mettre 5 étoiles à ce parc ?\nLes décors sont magnifiques, les attractions sont renouvelée tout les 5/10 ans. …',
#   'Super moment malgré le fait que beaucoup d’attractions soit fermé ( avec un prix qui ne change pas) . Tout est chers dans le parc mais c’est le jeu… après heureusement le pic nique est autorisé . MAGNIFIQUE parade bien organisée ! Personnel agréable. Énorme chance en hiver pas de queue a faire donc possibilité de voir énormément de chose',
#   "Disney ne m'a jamais déçu, la qualité de tout ce qu'ils proposent est spectaculaire, toutes les personnes qui y travaillent sont vraiment formées pour faire de votre visite une expérience inoubliable. Les jeux et attractions sont très bien …",
#   "Joli parc, pour les enfants, mais comparé à y a quelques années, c'est tombé bien bas, et les tarifs sont graves malades.\nParc mal entretenu, mal tondu, le personnel pas souriant, pas aimable, bref, …",
#   "Meilleur parc d'attraction de France, de loin. Une journée, mieux avec deux. L'enfant en vous reviendra à l'instant où vous entrerez dans ce parc et ce, quelque soit le nombre de fois où vous irez. Choisissez bien vos jours, lorsque c'est trop bondé, il est difficile d'en profiter pleinement.",
#   "On a A DO RE ! Tout était top pour satisfaire le visiteur, un bémol sur la réservation, en effet Disneyland s'est encaissé 20€ de plus, et n'a jamais eu la correction de répondre au courrier recommandé, et donc de rembourser le trop perçu. …",
#   'Parc est toujours aussi beau et bien entretenu, néanmoins les tarifs restent élevés sans que Disneyland ne se renouvelle plus que ça, et les pannes mécaniques sont assez fréquentes. Cependant, après une période COVID, cela peut se …',
#   "Un lieu magique féerique 😍 la magie est au rendez-vous la décoration et juste magnifique on voyage à travers le temps et le monde, le point négatif l'attente est vraiment longue, donc on ne pas faire plusieurs choses …",
#   "Journée magique 😍\nPremière fois pour mon fils de 4 ans, il a adoré, la magie est présente dès l'arrivée sur le parc. Nous avons eu un super temps, pas trop d'attente, nous avon …",
#   'Comment ne pas mettre 5 étoiles à ce parc ?\nLes décors sont magnifiques, les attractions sont renouvelée tout les 5/10 ans. …',
#   'Super moment malgré le fait que beaucoup d’attractions soit fermé ( avec un prix qui ne change pas) . Tout est chers dans le parc mais c’est le jeu… après heureusement le pic nique est autorisé . MAGNIFIQUE parade bien organisée ! Personnel agréable. Énorme chance en hiver pas de queue a faire donc possibilité de voir énormément de chose',
#   "Disney ne m'a jamais déçu, la qualité de tout ce qu'ils proposent est spectaculaire, toutes les personnes qui y travaillent sont vraiment formées pour faire de votre visite une expérience inoubliable. Les jeux et attractions sont très bien …",
#   'Disneyland Paris est de loin le meilleur parc d’attraction en Europe, idéal à tout âge. Tout est soigneusement bien conçu, aucun détail n’est laissé au hasard. Les mots ne peuvent pas décrire convenablement ce monde féerique et magique. Il …',
#   "Pour une première fois en famille c'est trop cool, sur les infrastructures j'adore, la propreté nickel dommage que certaines personnes ne soient pas en mesure de respecter les poubelles. …",
#   "J'avais une certaine appréhension en lisant les commentaires des internautes au sujet de cet endroit. Trop de monde, trop cher, trop d'attractions en panne... …",
#   'Nous sommes venus passer un week-end en famille dans ce magnifique parc .\nCelui ci est très propre et notre petite fille a été émerveillée du début à la fin! …',
#   "Formidable, je ne mets pas 5 étoiles car avec une personne à mobilité réduite, il nous a fallu plus d'une heure pour franchir les portes du parc. C'est une attente interminable surtout pour des personnes à problèmes de circulation. …",
#   "Ce lieu est toujours aussi magique 🦄 aussi bien pour les petits que pour les grands.\nLe seul bémol reste quand même les prix pour une famille de 4, c'est une journé …",
#   "Trois jours super malgré l'attente à certaine attractions. Des paillettes pleins les yeux pour ma fille, c'était sa première fois. On adore la musique des 30 ans spectacle du soir à ne pas manquer.",
#   'Parc merveilleux et féerique. A chaque nouvelle visite, je découvre des choses nouvelles ou des choses cachées que je vois pour la première fois, comme par exemple la caverne du dragon sous la boutique de verrerie. Le château est sublime. …',
xa0mois',
#   'il y a 7\xa0mois',
#   'il y a 3\xa0mois',
#   'il y a un mois',
#   'il y a 2\xa0mois',
#   'il y a 5\xa0jours',
#   'il y a 3\xa0mois',
#   'il y a 8\xa0mois',
#   '',
#   '',
#   '',
#   'il y a 3\xa0semaines',
#   'il y a 11\xa0mois',
#   'il y a 10\xa0mois',
#   'il y a un mois',
#   'il y a 6\xa0mois',
#   'il y a 6\xa0mois',
#   'il y a 6\xa0mois',
#   'il y a 3\xa0mois',
#   'il y a 2\xa0semaines',
#   'il y a 6\xa0mois',
#   'il y a un mois',
#   'il y a 10\xa0mois',
#   'il y a 4\xa0mois',
#   'il y a 2\xa0mois',
#   'il y a 7\xa0mois',
#   'il y a 7\xa0mois',
#   'il y a 9\xa0mois',
#   'il y a 4\xa0mois',
#   'il y a 4\xa0semaines',
#   'il y a 7\xa0mois',
#   'il y a un mois',
#   'il y a 2\xa0mois',
#   'il y a 11\xa0mois',
#   'il y a 7\xa0mois',
#   'il y a 3\xa0mois',
#   'il y a un mois',
#   'il y a 2\xa0mois',
#   'il y a 5\xa0jours',
#   'il y a 3\xa0mois',
#   'il y a 8\xa0mois'],
#  'Review Role': ['',
#   '',
#   'Local\xa0Guide',
#   'Local\xa0Guide',
#   'Local\xa0Guide',
#   'Local\xa0Guide',
#   'Local\xa0Guide',
#   'Local\xa0Guide',
#   'Local\xa0Guide',
#   'Local\xa0Guide',
#   'Local\xa0Guide',
#   'Local\xa0Guide',
#   'Local\xa0Guide',
#   'Local\xa0Guide',
#   'Local\xa0Guide',
#   'Local\xa0Guide',
#   'Local\xa0Guide',
#   'Local\xa0Guide',
#   'Local\xa0Guide',
#   'Local\xa0Guide',
#   'Local\xa0Guide',
#   'Local\xa0Guide',
#   'Local\xa0Guide',
#   'Local\xa0Guide',
#   'Local\xa0Guide',
#   'Local\xa0Guide',
#   'Local\xa0Guide',
#   'Local\xa0Guide',
#   'Local\xa0Guide',
#   'Local\xa0Guide',
#   'Local\xa0Guide',
#   'Local\xa0Guide',
#   'Local\xa0Guide',
#   'Local\xa0Guide',
#   'Local\xa0Guide',
#   'Local\xa0Guide',
#   'Local\xa0Guide',
#   'Local\xa0Guide',
#   'Local\xa0Guide',
#   'Local\xa0Guide',
#   'Local\xa0Guide',
#   'Local\xa0Guide',
#   'Local\xa0Guide',
#   'Local\xa0Guide',
#   'Local\xa0Guide',
#   'Local\xa0Guide',
#   'Local\xa0Guide',
#   'Local\xa0Guide',
#   'Local\xa0Guide',
#   'Local\xa0Guide',
#   'Local\xa0Guide',
#   'Local\xa0Guide',
#   'Local\xa0Guide',
#   'Local\xa0Guide',
#   'Local\xa0Guide',
#   'Local\xa0Guide',
#   'Local\xa0Guide',
#   'Local\xa0Guide',
#   'Local\xa0Guide',
#   'Local\xa0Guide',
#   'Local\xa0Guide',
#   'Local\xa0Guide',
#   '',
#   '',
#   '',
#   'Local\xa0Guide',
#   'Local\xa0Guide',
#   'Local\xa0Guide',
#   'Local\xa0Guide',
#   'Local\xa0Guide',
#   'Local\xa0Guide',
#   'Local\xa0Guide',
#   'Local\xa0Guide',
#   'Local\xa0Guide',
#   'Local\xa0Guide',
#   'Local\xa0Guide',
#   'Local\xa0Guide',
#   'Local\xa0Guide',
#   'Local\xa0Guide',
#   'Local\xa0Guide',
#   'Local\xa0Guide',
#   'Local\xa0Guide',
#   'Local\xa0Guide',
#   'Local\xa0Guide',
#   'Local\xa0Guide',
#   'Local\xa0Guide',
#   'Local\xa0Guide',
#   'Local\xa0Guide',
#   'Local\xa0Guide',
#   'Local\xa0Guide',
#   'Local\xa0Guide',
#   'Local\xa0Guide',
#   'Local\xa0Guide',
#   'Local\xa0Guide',
#   'Local\xa0Guide'],
#  'Review Rate': [' 3\xa0étoiles ',
#   ' 4\xa0étoiles ',
#   ' 5\xa0étoiles ',
#   ' 5\xa0étoiles ',
#   ' 3\xa0étoiles ',
#   ' 5\xa0étoiles ',
#   ' 4\xa0étoiles ',
#   ' 4\xa0étoiles ',
#   ' 5\xa0étoiles ',
#   ' 5\xa0étoiles ',
#   ' 5\xa0étoiles ',
#   ' 4\xa0étoiles ',
#   ' 5\xa0étoiles ',
#   ' 5\xa0étoiles ',
#   ' 5\xa0étoiles ',
#   ' 5\xa0étoiles ',
#   ' 5\xa0étoiles ',
#   ' 4\xa0étoiles ',
#   ' 5\xa0étoiles ',
#   ' 4\xa0étoiles ',
#   ' 5\xa0étoiles ',
#   ' 5\xa0étoiles ',
#   ' 5\xa0étoiles ',
#   ' 4\xa0étoiles ',
#   ' 5\xa0étoiles ',
#   ' 5\xa0étoiles ',
#   ' 4\xa0étoiles ',
#   ' 5\xa0étoiles ',
#   ' 5\xa0étoiles ',
#   ' 5\xa0étoiles ',
#   ' 3\xa0étoiles ',
#   ' 4\xa0étoiles ',
#   ' 5\xa0étoiles ',
#   ' 5\xa0étoiles ',
#   ' 3\xa0étoiles ',
#   ' 5\xa0étoiles ',
#   ' 4\xa0étoiles ',
#   ' 4\xa0étoiles ',
#   ' 5\xa0étoiles ',
#   ' 5\xa0étoiles ',
#   ' 5\xa0étoiles ',
#   ' 4\xa0étoiles ',
#   ' 5\xa0étoiles ',
#   ' 5\xa0étoiles ',
#   ' 5\xa0étoiles ',
#   ' 5\xa0étoiles ',
#   ' 5\xa0étoiles ',
#   ' 4\xa0étoiles ',
#   ' 5\xa0étoiles ',
#   ' 4\xa0étoiles ',
#   ' 5\xa0étoiles ',
#   ' 5\xa0étoiles ',
#   ' 5\xa0étoiles ',
#   ' 4\xa0étoiles ',
#   ' 5\xa0étoiles ',
#   ' 5\xa0étoiles ',
#   ' 4\xa0étoiles ',
#   ' 5\xa0étoiles ',
#   ' 5\xa0étoiles ',
#   ' 5\xa0étoiles ',
#   ' 3\xa0étoiles ',
#   ' 4\xa0étoiles ',
#   ' 5\xa0étoiles ',
#   ' 5\xa0étoiles ',
#   ' 3\xa0étoiles ',
#   ' 5\xa0étoiles ',
#   ' 4\xa0étoiles ',
#   ' 4\xa0étoiles ',
#   ' 5\xa0étoiles ',
#   ' 5\xa0étoiles ',
#   ' 5\xa0étoiles ',
#   ' 4\xa0étoiles ',
#   ' 5\xa0étoiles ',
#   ' 5\xa0étoiles ',
#   ' 5\xa0étoiles ',
#   ' 5\xa0étoiles ',
#   ' 5\xa0étoiles ',
#   ' 4\xa0étoiles ',
#   ' 5\xa0étoiles ',
#   ' 4\xa0étoiles ',
#   ' 5\xa0étoiles ',
#   ' 5\xa0étoiles ',
#   ' 5\xa0étoiles ',
#   ' 4\xa0étoiles ',
#   ' 5\xa0étoiles ',
#   ' 5\xa0étoiles ',
#   ' 4\xa0étoiles ',
#   ' 5\xa0étoiles ',
#   ' 5\xa0étoiles ',
#   ' 5\xa0étoiles ']}

# %%
d=pd.DataFrame(rev_dict)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9272\2377935530.py in <module>
# ----> 1 d=pd.DataFrame(rev_dict)
#
# ~\anaconda3\envs\DineyProject\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     634         elif isinstance(data, dict):
#     635             # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 636             mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     637         elif isinstance(data, ma.MaskedArray):
#     638             import numpy.ma.mrecords as mrecords
#
# ~\anaconda3\envs\DineyProject\lib\site-packages\pandas\core\internals\construction.py in dict_to_mgr(data, index, columns, dtype, typ, copy)
#     500         # TODO: can we get rid of the dt64tz special case above?
#     501
# --> 502     return arrays_to_mgr(arrays, columns, index, dtype=dtype, typ=typ, consolidate=copy)
#     503
#     504
#
# ~\anaconda3\envs\DineyProject\lib\site-packages\pandas\core\internals\construction.py in arrays_to_mgr(arrays, columns, index, dtype, verify_integrity, typ, consolidate)
#     118         # figure out the index, if necessary
#     119         if index is None:
# --> 120             index = _extract_index(arrays)
#     121         else:
#     122             index = ensure_index(index)
#
# ~\anaconda3\envs\DineyProject\lib\site-packages\pandas\core\internals\construction.py in _extract_index(data)
#     672             lengths = list(set(raw_lengths))
#     673             if len(lengths) > 1:
# --> 674                 raise ValueError("All arrays must be of the same length")
#     675
#     676             if have_dicts:
#
# ValueError: All arrays must be of the same length

# %%
d.to_csv("Disneyland.csv",sep=',',index=False, header=False,)

# %%
rev_dict['Review Time']
# Out:
# ['',
#  '',
#  'il y a 3\xa0semaines',
#  'il y a 11\xa0mois',
#  'il y a 10\xa0mois',
#  'il y a un mois',
#  'il y a 6\xa0mois',
#  'il y a 6\xa0mois',
#  'il y a 6\xa0mois',
#  'il y a 3\xa0mois',
#  'il y a 2\xa0semaines',
#  'il y a 6\xa0mois',
#  'il y a un mois',
#  'il y a 10\xa0mois',
#  'il y a 4\xa0mois',
#  'il y a 2\xa0mois',
#  'il y a 7\xa0mois',
#  'il y a 7\xa0mois',
#  'il y a 9\xa0mois',
#  'il y a 4\xa0mois',
#  'il y a 4\xa0semaines',
#  'il y a 7\xa0mois',
#  'il y a un mois',
#  'il y a 2\xa0mois',
#  'il y a 11\xa0mois',
#  'il y a 7\xa0mois',
#  'il y a 3\xa0mois',
#  'il y a un mois',
#  'il y a 2\xa0mois',
#  'il y a 5\xa0jours',
#  'il y a 3\xa0mois',
#  'il y a 8\xa0mois',
#  'il y a 3\xa0semaines',
#  'il y a 11\xa0mois',
#  'il y a 10\xa0mois',
#  'il y a un mois',
#  'il y a 6\xa0mois',
#  'il y a 6\xa0mois',
#  'il y a 6\xa0mois',
#  'il y a 3\xa0mois',
#  'il y a 2\xa0semaines',
#  'il y a 6\xa0mois',
#  'il y a un mois',
#  'il y a 10\xa0mois',
#  'il y a 4\xa0mois',
#  'il y a 2\xa0mois',
#  'il y a 7\xa0mois',
#  'il y a 7\xa0mois',
#  'il y a 9\xa0mois',
#  'il y a 4\xa0mois',
#  'il y a 4\xa0semaines',
#  'il y a 7\xa0mois',
#  'il y a un mois',
#  'il y a 2\xa0mois',
#  'il y a 11\xa0mois',
#  'il y a 7\xa0mois',
#  'il y a 3\xa0mois',
#  'il y a un mois',
#  'il y a 2\xa0mois',
#  'il y a 5\xa0jours',
#  'il y a 3\xa0mois',
#  'il y a 8\xa0mois',
#  '',
#  '',
#  '',
#  'il y a 3\xa0semaines',
#  'il y a 11\xa0mois',
#  'il y a 10\xa0mois',
#  'il y a un mois',
#  'il y a 6\xa0mois',
#  'il y a 6\xa0mois',
#  'il y a 6\xa0mois',
#  'il y a 3\xa0mois',
#  'il y a 2\xa0semaines',
#  'il y a 6\xa0mois',
#  'il y a un mois',
#  'il y a 10\xa0mois',
#  'il y a 4\xa0mois',
#  'il y a 2\xa0mois',
#  'il y a 7\xa0mois',
#  'il y a 7\xa0mois',
#  'il y a 9\xa0mois',
#  'il y a 4\xa0mois',
#  'il y a 4\xa0semaines',
#  'il y a 7\xa0mois',
#  'il y a un mois',
#  'il y a 2\xa0mois',
#  'il y a 11\xa0mois',
#  'il y a 7\xa0mois',
#  'il y a 3\xa0mois',
#  'il y a un mois',
#  'il y a 2\xa0mois',
#  'il y a 5\xa0jours',
#  'il y a 3\xa0mois',
#  'il y a 8\xa0mois']
